# %% [markdown]
# # Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data. (2.5 points)

# %%
import pandas as pd

# %%
df=pd.read_csv("Laliga.csv")
df.head(10)
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0        Pos             Team    Seasons     Points  GamesPlayed   GamesWon
# 1          1      Real Madrid         86       4385         2762       1647
# 2          2        Barcelona         86       4262         2762       1581
# 3          3  Atletico Madrid         80       3442         2614       1241
# 4          4         Valencia         82       3386         2664       1187
# 5          5  Athletic Bilbao         86       3368         2762       1209
# 6          6          Sevilla         73       2819         2408        990
# 7          7         Espanyol         82       2792         2626        948
# 8          8    Real Sociedad         70       2573         2302        864
# 9          9         Zaragoza         58       2109         1986        698
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...

# %%
new_header = df.iloc[0] 
df = df[1:] 
df.columns = new_header 
df.head()
# Out:
# 0 Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86   4385        2762     1647        552
# 2   2        Barcelona      86   4262        2762     1581        573
# 3   3  Atletico Madrid      80   3442        2614     1241        598
# 4   4         Valencia      82   3386        2664     1187        616
# 5   5  Athletic Bilbao      86   3368        2762     1209        633
#
# 0 GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 1       563     5947         3140       33        23     8      8     3     4
# 2       608     5900         3114       25        25    12     12     4     6
# 3       775     4534         3309       10         8    16      9     7     6
# 4       861     4398         3469        6         6    10     11    10     7
# 5       920     4631         3700        8         7    10      5     8    10
#
# 0   T    Debut Since/LastApp BestPosition
# ...

# %%
df.set_index('Pos',inplace=True)

# %%
df.head()
# Out:
# 0               Team Seasons Points GamesPlayed GamesWon GamesDrawn GamesLost  \
# Pos
# 1        Real Madrid      86   4385        2762     1647        552       563
# 2          Barcelona      86   4262        2762     1581        573       608
# 3    Atletico Madrid      80   3442        2614     1241        598       775
# 4           Valencia      82   3386        2664     1187        616       861
# 5    Athletic Bilbao      86   3368        2762     1209        633       920
#
# 0   GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth   T  \
# Pos
# 1       5947         3140       33        23     8      8     3     4  79
# 2       5900         3114       25        25    12     12     4     6  83
# 3       4534         3309       10         8    16      9     7     6  56
# 4       4398         3469        6         6    10     11    10     7  50
# 5       4631         3700        8         7    10      5     8    10  49
#
# 0      Debut Since/LastApp BestPosition
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 1 to 61
# Data columns (total 19 columns):
# Team             61 non-null object
# Seasons          61 non-null object
# Points           61 non-null object
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner-up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null object
# dtypes: object(19)
# memory usage: 9.5+ KB

# %%
df.replace(to_replace =["-"],value=0,inplace=True)

# %%
df.head(61)
# Out:
# 0                   Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1            Real Madrid      86   4385        2762     1647        552
# 2              Barcelona      86   4262        2762     1581        573
# 3        Atletico Madrid      80   3442        2614     1241        598
# 4               Valencia      82   3386        2664     1187        616
# 5        Athletic Bilbao      86   3368        2762     1209        633
# 6                Sevilla      73   2819        2408      990        531
# 7               Espanyol      82   2792        2626      948        608
# 8          Real Sociedad      70   2573        2302      864        577
# 9               Zaragoza      58   2109        1986      698        522
# 10            Real Betis      51   1884        1728      606        440
# 11   Deportivo La Coruna      45   1814        1530      563        392
# 12            Celta Vigo      51   1789        1698      586        389
# ...

# %% [markdown]
# # Print all the teams which have started playing between 1930-1980. (5 points)

# %%
df[['Debut Start','Debut End']] = df.Debut.str.split("-",expand=True) 
df.drop('Debut End',axis=1,inplace=True)

# %%
df['Debut Start'] = df['Debut Start'].apply(pd.to_numeric)

# %%
df1=df[(df['Debut Start'] <= 1980)&(df['Debut Start'] >= 1930)]

# %%
df1
# Out:
# 0                   Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 4               Valencia      82   3386        2664     1187        616
# 6                Sevilla      73   2819        2408      990        531
# 9               Zaragoza      58   2109        1986      698        522
# 10            Real Betis      51   1884        1728      606        440
# 11   Deportivo La Coruna      45   1814        1530      563        392
# 12            Celta Vigo      51   1789        1698      586        389
# 13            Valladolid      42   1471        1466      463        384
# 15        Sporting Gijon      43   1389        1458      471        358
# 16               Osasuna      37   1351        1318      426        327
# 17                Malaga      36   1314        1255      390        330
# 18                Oviedo      38   1174        1192      408        292
# 19              Mallorca      27   1148         988      333        256
# ...

# %%
df1.shape
# Out:
# (37, 20)

# %% [markdown]
# # Print the list of teams which came Top 5 in terms of points (2.5 points)

# %%
df['Points'] = df['Points'].apply(pd.to_numeric)
df2=df.sort_values(by=['Points'],ascending=False)[0:5]
df2
# Out:
# 0               Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid      86    4385        2762     1647        552
# 2          Barcelona      86    4262        2762     1581        573
# 3    Atletico Madrid      80    3442        2614     1241        598
# 4           Valencia      82    3386        2664     1187        616
# 5    Athletic Bilbao      86    3368        2762     1209        633
#
# 0   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# Pos
# 1         563     5947         3140       33        23     8      8     3
# 2         608     5900         3114       25        25    12     12     4
# 3         775     4534         3309       10         8    16      9     7
# 4         861     4398         3469        6         6    10     11    10
# 5         920     4631         3700        8         7    10      5     8
#
# 0   Sixth   T    Debut Since/LastApp BestPosition  Debut Start
# Pos
# ...

# %%
df2[["Team","Points"]]
# Out:
# 0               Team  Points
# Pos
# 1        Real Madrid    4385
# 2          Barcelona    4262
# 3    Atletico Madrid    3442
# 4           Valencia    3386
# 5    Athletic Bilbao    3368

# %% [markdown]
# # Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)

# %% [markdown]
# Goal_diff_count = GoalsFor - GoalsAgainst

# %%
df['GoalsFor'] = df['GoalsFor'].apply(pd.to_numeric)
df['GoalsAgainst'] = df['GoalsAgainst'].apply(pd.to_numeric)

# %%
def Goal_diff_count(a,b):
    return (a-b)

# %%
df['GoalDiffCount'] = df.apply(lambda df: Goal_diff_count(df['GoalsFor'], df['GoalsAgainst']), axis=1)

# %%
df
# Out:
# 0                   Team Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# Pos
# 1            Real Madrid      86    4385        2762     1647        552
# 2              Barcelona      86    4262        2762     1581        573
# 3        Atletico Madrid      80    3442        2614     1241        598
# 4               Valencia      82    3386        2664     1187        616
# 5        Athletic Bilbao      86    3368        2762     1209        633
# 6                Sevilla      73    2819        2408      990        531
# 7               Espanyol      82    2792        2626      948        608
# 8          Real Sociedad      70    2573        2302      864        577
# 9               Zaragoza      58    2109        1986      698        522
# 10            Real Betis      51    1884        1728      606        440
# 11   Deportivo La Coruna      45    1814        1530      563        392
# 12            Celta Vigo      51    1789        1698      586        389
# ...

# %%
df.loc[(df['GoalDiffCount'] == df['GoalDiffCount'].max())]["Team"]
# Out:
# Pos
# 1    Real Madrid
# Name: Team, dtype: object

# %%
df.loc[(df['GoalDiffCount'] == df['GoalDiffCount'].min())]["Team"]
# Out:
# Pos
# 14    Racing Santander
# Name: Team, dtype: object

# %% [markdown]
# # Create a new column with name “Winning Percent” and append it to the data set (5 points)
# Percentage of Winning = (GamesWon / GamesPlayed)*100

# %%
def winning_perc(a,b):
    if a==0 or b==0:
        return 0
    else:
        c=(a/b)*100
        return c

# %%
df['GamesWon'] = df['GamesWon'].apply(pd.to_numeric)
df['GamesPlayed'] = df['GamesPlayed'].apply(pd.to_numeric)

# %%
df['Winning Percent'] = df.apply(lambda df: winning_perc(df['GamesWon'], df['GamesPlayed']), axis=1)

# %%
df
# Out:
# 0                   Team Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# Pos
# 1            Real Madrid      86    4385         2762      1647        552
# 2              Barcelona      86    4262         2762      1581        573
# 3        Atletico Madrid      80    3442         2614      1241        598
# 4               Valencia      82    3386         2664      1187        616
# 5        Athletic Bilbao      86    3368         2762      1209        633
# 6                Sevilla      73    2819         2408       990        531
# 7               Espanyol      82    2792         2626       948        608
# 8          Real Sociedad      70    2573         2302       864        577
# 9               Zaragoza      58    2109         1986       698        522
# 10            Real Betis      51    1884         1728       606        440
# 11   Deportivo La Coruna      45    1814         1530       563        392
# ...

# %% [markdown]
# # Print the top 5 teams which has the highest Winning percentage

# %%
dfw=df.sort_values(by=['Winning Percent'],ascending=False)[0:5]
dfw
# Out:
# 0               Team Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# Pos
# 1        Real Madrid      86    4385         2762      1647        552
# 2          Barcelona      86    4262         2762      1581        573
# 3    Atletico Madrid      80    3442         2614      1241        598
# 4           Valencia      82    3386         2664      1187        616
# 5    Athletic Bilbao      86    3368         2762      1209        633
#
# 0   GamesLost  GoalsFor  GoalsAgainst Champion  ... Fourth Fifth Sixth   T  \
# Pos                                             ...
# 1         563      5947          3140       33  ...      8     3     4  79
# 2         608      5900          3114       25  ...     12     4     6  83
# 3         775      4534          3309       10  ...      9     7     6  56
# 4         861      4398          3469        6  ...     11    10     7  50
# 5         920      4631          3700        8  ...      5     8    10  49
#
# ...

# %%
dfw[["Team","Winning Percent"]]
# Out:
# 0               Team  Winning Percent
# Pos
# 1        Real Madrid        59.630702
# 2          Barcelona        57.241130
# 3    Atletico Madrid        47.475134
# 4           Valencia        44.557057
# 5    Athletic Bilbao        43.772629

# %% [markdown]
# # Group teams based on their “Best position” and print the sum of their points for all positions (5 points)
# Eg: Best Position                     Points
#         1                              25000
#         2                              7000

# %%
df['BestPosition'] = df['BestPosition'].apply(pd.to_numeric)

# %%
groupedByChampion=df.groupby('BestPosition').sum()
dfsort=groupedByChampion.sort_values(by='BestPosition',ascending=True,axis=0)
dfsort.iloc[0:,[0]]
# Out:
# 0             Points
# BestPosition
# 1              27933
# 2               6904
# 3               5221
# 4               6563
# 5               1884
# 6               2113
# 7               1186
# 8               1134
# 9                 96
# 10               450
# 11               445
# 12               511
# 14                71
# 15                14
# 16                81
# 17               266
# 19                81
# 20                34
